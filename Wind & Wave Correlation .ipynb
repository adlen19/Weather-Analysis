# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_excel('Complied Data Final Backup 2020.xlsx')

# %%
df.head(1)
# Out:
#   Vessel Name               Date   Wind Speed     Wind Dir Wind & COG  \
# 3      ACAMAR 2020-01-03 11:00:00     8.061575  223.098068      DRIFT
#
#    Wave Ht     Wave Dir Wave & COG  Current  Adj Speed Current   ...  \
# 3  1.832839  314.365906    HEAD ON      0.0                 0.0  ...
#
#    Propeller BLADES  ECO/NON ECO  Class  Declared Consumptions (Laden)  \
# 3               NaN          NaN    NaN                           23.0
#
#    Declared Consumptions (Ballast)  UW Service Date   UW Service Type  \
# 3                             21.0               NaN              NaN
#
#    UW Service Port  UW Service Vendor  UW Service Line
# 3               NaN               NaN              NaN
#
# [1 rows x 98 columns]

# %%
df = df[(df['Wind Speed '] > 0) & (df['Wind Speed '] < 21.5) & (df['Wave Ht '] > 0) & (df['Wave Ht '] < 2.5) & (df['Wave Ht '] < 7.3) & (df['Wave Dir'] > 0) & (df['Wave Dir'] > 0)]

# %%
print(df.columns.tolist())
# Out:
# ['Vessel Name', 'Date ', 'Wind Speed ', 'Wind Dir', 'Wind & COG', 'Wave Ht ', 'Wave Dir', 'Wave & COG', 'Current', 'Adj Speed Current ', 'COG', 'RPM', 'Avg Draft', 'Normalized Draft', 'Normalized Speed', 'SOG', 'Ordered Speed', 'SOW', 'Ordered Speed.1', 'Power Reported', 'Adjusted Draft Power', 'Adj Speed Reported Powed', 'FC Reported', 'Adjusted Draft FC', 'Adjusted Speed FC', 'Oil Type ', 'Predicted Power', 'Adjusted Draft  Predicted Power', 'Adj Speed Pred Power ', 'Predicted FC', 'Adjusted Draft  Predicted FC', 'Adj Speed Pred FC ', 'Power Error', 'FC Error', 'ABS Power Error', 'ABS FC Error', 'SFOC Measured ', 'SFOC Corrected ', 'Steaming Hours', 'Lat ', 'Long', 'Tropical/Non-Tropical', 'Port Name (Not-Corrected)', 'Sailing/Port Days', 'Distance', 'Cargo', 'Fuel Economy', 'Laden or Ballast (IMOS)', 'FC Error (Neg)', 'ABS FC Error (Neg)', 'Beaufort Sea State (Wind)', 'Beaufort Sea State (Wave)', 'Beaufort Sea State ', 'Normalised Ballast Draft', 'Normalised Design Draft ', 'Pool 
# ...

# %%
df.describe()
# Out:
#         Wind Speed       Wind Dir      Wave Ht       Wave Dir       Current  \
# count  24571.000000  24571.000000  24571.000000  24571.000000  24571.000000
# mean      11.767607    167.352514      1.222207    173.055178     -0.010432
# std        4.298651    103.389894      0.617200     97.144934      0.377417
# min        0.108116      0.000000      0.012463      5.070055     -3.241585
# 25%        8.448767     76.056175      0.694815     91.267517     -0.172270
# 50%       11.576791    157.182617      1.220169    172.394196      0.000000
# 75%       14.942602    253.520729      1.686471    248.448669      0.155908
# max       21.496469    360.000000      2.499760    359.999939      2.718540
#
#        Adj Speed Current            COG           RPM     Avg Draft  \
# count             24546.0  24571.000000  24571.000000  24571.000000
# mean                  0.0    179.140705     71.584331      9.983017
# std                   0.0    158.552562     17.633005     20.246714
# ...

# %%
dff = df.filter(['Wind Speed ','Wave Ht ','Wind Dir', 'Current','Wave Dir'], axis=1)

# %%
dff.head(1)
# Out:
#    Wind Speed   Wave Ht     Wind Dir  Current    Wave Dir
# 3     8.061575  1.832839  223.098068      0.0  314.365906

# %%
# dff = dff.dropna()

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
sns.set_style('darkgrid')

# %%
import seaborn as sns
sns.set_style('darkgrid')
sns.pairplot(dff);

# %% [markdown]
# #  ML model for Wind speed and Wave height

# %%
from sklearn import linear_model
# %matplotlib inline

# %%
plt.scatter(dff['Wind Speed '] ,dff['Wave Ht '])
plt.xlabel('Wind speed (Knot)')
plt.ylabel('Wave height (m)')
plt.title('Corelation btw Wind speed and Wave Height')
# Out:
# Text(0.5, 1.0, 'Corelation btw Wind speed and Wave Height')

# %%
max_threshold = dff['Wave Ht '].quantile(1)

# %%
max_threshold
# Out:
# 2.49975967407227

# %% [markdown]
# # Implemented a Linear Regression Model

# %%
# inputs = dff['Wind Speed ','Wind Dir']
inputs = df.filter(['Wind Speed ','Wind Dir'], axis=1)
target = dff['Wave Ht ']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size = 0.4)

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)   #training the model
# Out:
# LinearRegression()

# %%
reg.score(X_test,y_test)
# Out:
# 0.2390465588518339

# %% [markdown]
# # Conclusion: Very Poor score hence try a difrent Model i.e. Logistic Regression
